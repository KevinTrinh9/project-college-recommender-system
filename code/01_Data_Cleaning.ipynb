# %% [markdown]
# # Capstone Project - College Recommender System

# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd

# %%
data = pd.read_csv('data/MERGED2022_23_PP.csv', low_memory=False)

# %%
data.head()
# Out:
#    UNITID      OPEID   OPEID6                               INSTNM  \
# 0  100654   100200.0   1002.0             Alabama A & M University
# 1  100663   105200.0   1052.0  University of Alabama at Birmingham
# 2  100690  2503400.0  25034.0                   Amridge University
# 3  100706   105500.0   1055.0  University of Alabama in Huntsville
# 4  100724   100500.0   1005.0             Alabama State University
#
#          CITY STABBR         ZIP  \
# 0      Normal     AL       35762
# 1  Birmingham     AL  35294-0110
# 2  Montgomery     AL  36117-3553
# 3  Huntsville     AL       35899
# 4  Montgomery     AL  36104-0271
#
#                                         ACCREDAGENCY  \
# 0  Southern Association of Colleges and Schools C...
# 1  Southern Association of Colleges and Schools C...
# 2  Southern Association of Colleges and Schools C...
# 3  Southern Association of Colleges and Schools C...
# 4  Southern Association of Colleges and Schools C...
#
# ...

# %%
# select specific columns
selected_columns = ['INSTNM', 'CITY', 'STABBR', 'INSTURL', 'PREDDEG', 'HIGHDEG', 'ADM_RATE', 'SAT_AVG', 'CURROPER', 'ADDR']
columns_to_keep = []
columns_to_keep.extend(selected_columns)
for column_name in data.columns:
    if column_name.startswith('PCIP'):
        columns_to_keep.append(column_name)
data = data[columns_to_keep]

# %%
data.head()
# Out:
#                                 INSTNM        CITY STABBR  \
# 0             Alabama A & M University      Normal     AL
# 1  University of Alabama at Birmingham  Birmingham     AL
# 2                   Amridge University  Montgomery     AL
# 3  University of Alabama in Huntsville  Huntsville     AL
# 4             Alabama State University  Montgomery     AL
#
#                               INSTURL  PREDDEG  HIGHDEG  ADM_RATE  SAT_AVG  \
# 0                       www.aamu.edu/        3        4    0.6840    920.0
# 1                https://www.uab.edu/        3        4    0.8668   1291.0
# 2  https://www.amridgeuniversity.edu/        3        4       NaN      NaN
# 3                        www.uah.edu/        3        4    0.7810   1259.0
# 4                      www.alasu.edu/        3        4    0.9660    963.0
#
#    CURROPER                            ADDR  ...  PCIP44  PCIP45  PCIP46  \
# 0         1            4900 Meridian Street  ...  0.0431  0.0313     0.0
# ...

# %%
data.tail()
# Out:
#                                                  INSTNM         CITY STABBR  \
# 6479                   Wilton Simpson Technical College  Brooksville     FL
# 6480      Valley College - Fairlawn - School of Nursing     Fairlawn     OH
# 6481  Western Maricopa Education Center - Southwest ...      Buckeye     AZ
# 6482  Western Maricopa Education Center - Northeast ...      Phoenix     AZ
# 6483  Burlington County Institute of Technology - Ad...      Medford     NJ
#
#                                       INSTURL  PREDDEG  HIGHDEG  ADM_RATE  \
# 6479  https://hernandoschools.org/schools/stc        0        0       NaN
# 6480                  https://www.valley.edu/        0        0       NaN
# 6481      https://west-mec.edu/findyourhappy/        0        0       NaN
# 6482      https://west-mec.edu/findyourhappy/        0        0       NaN
# 6483          https://www.bcit.cc/bcitadulted        0        0       NaN
#
# ...

# %%
data
# Out:
#                                                  INSTNM         CITY STABBR  \
# 0                              Alabama A & M University       Normal     AL
# 1                   University of Alabama at Birmingham   Birmingham     AL
# 2                                    Amridge University   Montgomery     AL
# 3                   University of Alabama in Huntsville   Huntsville     AL
# 4                              Alabama State University   Montgomery     AL
# ...                                                 ...          ...    ...
# 6479                   Wilton Simpson Technical College  Brooksville     FL
# 6480      Valley College - Fairlawn - School of Nursing     Fairlawn     OH
# 6481  Western Maricopa Education Center - Southwest ...      Buckeye     AZ
# 6482  Western Maricopa Education Center - Northeast ...      Phoenix     AZ
# 6483  Burlington County Institute of Technology - Ad...      Medford     NJ
#
# ...

# %%
data.shape
# Out:
# (6484, 48)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6484 entries, 0 to 6483
# Data columns (total 48 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   INSTNM    6484 non-null   object
#  1   CITY      6484 non-null   object
#  2   STABBR    6484 non-null   object
#  3   INSTURL   6460 non-null   object
#  4   PREDDEG   6484 non-null   int64
#  5   HIGHDEG   6484 non-null   int64
#  6   ADM_RATE  1956 non-null   float64
#  7   SAT_AVG   1089 non-null   float64
#  8   CURROPER  6484 non-null   int64
#  9   ADDR      5986 non-null   object
#  10  PCIP01    5711 non-null   float64
#  11  PCIP03    5711 non-null   float64
#  12  PCIP04    5711 non-null   float64
#  13  PCIP05    5711 non-null   float64
#  14  PCIP09    5711 non-null   float64
#  15  PCIP10    5711 non-null   float64
#  16  PCIP11    5711 non-null   float64
#  17  PCIP12    5711 non-null   float64
#  18  PCIP13    5711 non-null   float64
#  19  PCIP14    5711 non-null   float64
# ...

# %%
# check for duplicates in df
data.duplicated().sum()
# Out:
# 0

# %%
# count missing values in df
data.isna().sum()
# Out:
# INSTNM         0
# CITY           0
# STABBR         0
# INSTURL       24
# PREDDEG        0
# HIGHDEG        0
# ADM_RATE    4528
# SAT_AVG     5395
# CURROPER       0
# ADDR         498
# PCIP01       773
# PCIP03       773
# PCIP04       773
# PCIP05       773
# PCIP09       773
# PCIP10       773
# PCIP11       773
# PCIP12       773
# PCIP13       773
# PCIP14       773
# PCIP15       773
# PCIP16       773
# PCIP19       773
# PCIP22       773
# PCIP23       773
# PCIP24       773
# PCIP25       773
# PCIP26       773
# PCIP27       773
# PCIP29       773
# PCIP30       773
# PCIP31       773
# PCIP38       773
# PCIP39       773
# PCIP40       773
# PCIP41       773
# PCIP42       773
# PCIP43       773
# PCIP44       773
# PCIP45       773
# PCIP46       773
# PCIP47       773
# PCIP48       773
# PCIP49       773
# PCIP50       773
# PCIP51       773
# PCIP52       773
# PCIP54       773
# dtype: int64

# %%
# replace missing values in specific columns with "Not Available"
columns_to_fill = ['INSTURL', 'ADM_RATE', 'SAT_AVG', 'ADDR']
replacement_value = "Not Available"
data.fillna({col: replacement_value for col in columns_to_fill}, inplace=True)

# %%
data.head()
# Out:
#                                 INSTNM        CITY STABBR  \
# 0             Alabama A & M University      Normal     AL
# 1  University of Alabama at Birmingham  Birmingham     AL
# 2                   Amridge University  Montgomery     AL
# 3  University of Alabama in Huntsville  Huntsville     AL
# 4             Alabama State University  Montgomery     AL
#
#                               INSTURL  PREDDEG  HIGHDEG       ADM_RATE  \
# 0                       www.aamu.edu/        3        4          0.684
# 1                https://www.uab.edu/        3        4         0.8668
# 2  https://www.amridgeuniversity.edu/        3        4  Not Available
# 3                        www.uah.edu/        3        4          0.781
# 4                      www.alasu.edu/        3        4          0.966
#
#          SAT_AVG  CURROPER                            ADDR  ...  PCIP44  \
# 0          920.0         1            4900 Meridian Street  ...  0.0431
# ...

# %%
data.isna().sum()
# Out:
# INSTNM        0
# CITY          0
# STABBR        0
# INSTURL       0
# PREDDEG       0
# HIGHDEG       0
# ADM_RATE      0
# SAT_AVG       0
# CURROPER      0
# ADDR          0
# PCIP01      773
# PCIP03      773
# PCIP04      773
# PCIP05      773
# PCIP09      773
# PCIP10      773
# PCIP11      773
# PCIP12      773
# PCIP13      773
# PCIP14      773
# PCIP15      773
# PCIP16      773
# PCIP19      773
# PCIP22      773
# PCIP23      773
# PCIP24      773
# PCIP25      773
# PCIP26      773
# PCIP27      773
# PCIP29      773
# PCIP30      773
# PCIP31      773
# PCIP38      773
# PCIP39      773
# PCIP40      773
# PCIP41      773
# PCIP42      773
# PCIP43      773
# PCIP44      773
# PCIP45      773
# PCIP46      773
# PCIP47      773
# PCIP48      773
# PCIP49      773
# PCIP50      773
# PCIP51      773
# PCIP52      773
# PCIP54      773
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isna().sum()
# Out:
# INSTNM      0
# CITY        0
# STABBR      0
# INSTURL     0
# PREDDEG     0
# HIGHDEG     0
# ADM_RATE    0
# SAT_AVG     0
# CURROPER    0
# ADDR        0
# PCIP01      0
# PCIP03      0
# PCIP04      0
# PCIP05      0
# PCIP09      0
# PCIP10      0
# PCIP11      0
# PCIP12      0
# PCIP13      0
# PCIP14      0
# PCIP15      0
# PCIP16      0
# PCIP19      0
# PCIP22      0
# PCIP23      0
# PCIP24      0
# PCIP25      0
# PCIP26      0
# PCIP27      0
# PCIP29      0
# PCIP30      0
# PCIP31      0
# PCIP38      0
# PCIP39      0
# PCIP40      0
# PCIP41      0
# PCIP42      0
# PCIP43      0
# PCIP44      0
# PCIP45      0
# PCIP46      0
# PCIP47      0
# PCIP48      0
# PCIP49      0
# PCIP50      0
# PCIP51      0
# PCIP52      0
# PCIP54      0
# dtype: int64

# %%
data.shape
# Out:
# (5711, 48)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5711 entries, 0 to 5988
# Data columns (total 48 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   INSTNM    5711 non-null   object
#  1   CITY      5711 non-null   object
#  2   STABBR    5711 non-null   object
#  3   INSTURL   5711 non-null   object
#  4   PREDDEG   5711 non-null   int64
#  5   HIGHDEG   5711 non-null   int64
#  6   ADM_RATE  5711 non-null   object
#  7   SAT_AVG   5711 non-null   object
#  8   CURROPER  5711 non-null   int64
#  9   ADDR      5711 non-null   object
#  10  PCIP01    5711 non-null   float64
#  11  PCIP03    5711 non-null   float64
#  12  PCIP04    5711 non-null   float64
#  13  PCIP05    5711 non-null   float64
#  14  PCIP09    5711 non-null   float64
#  15  PCIP10    5711 non-null   float64
#  16  PCIP11    5711 non-null   float64
#  17  PCIP12    5711 non-null   float64
#  18  PCIP13    5711 non-null   float64
#  19  PCIP14    5711 non-null   float64
# ...

# %%
data.dtypes
# Out:
# INSTNM       object
# CITY         object
# STABBR       object
# INSTURL      object
# PREDDEG       int64
# HIGHDEG       int64
# ADM_RATE     object
# SAT_AVG      object
# CURROPER      int64
# ADDR         object
# PCIP01      float64
# PCIP03      float64
# PCIP04      float64
# PCIP05      float64
# PCIP09      float64
# PCIP10      float64
# PCIP11      float64
# PCIP12      float64
# PCIP13      float64
# PCIP14      float64
# PCIP15      float64
# PCIP16      float64
# PCIP19      float64
# PCIP22      float64
# PCIP23      float64
# PCIP24      float64
# PCIP25      float64
# PCIP26      float64
# PCIP27      float64
# PCIP29      float64
# PCIP30      float64
# PCIP31      float64
# PCIP38      float64
# PCIP39      float64
# PCIP40      float64
# PCIP41      float64
# PCIP42      float64
# PCIP43      float64
# PCIP44      float64
# PCIP45      float64
# PCIP46      float64
# PCIP47      float64
# PCIP48      float64
# PCIP49      float64
# PCIP50      float64
# ...

# %%
data
# Out:
#                                        INSTNM        CITY STABBR  \
# 0                    Alabama A & M University      Normal     AL
# 1         University of Alabama at Birmingham  Birmingham     AL
# 2                          Amridge University  Montgomery     AL
# 3         University of Alabama in Huntsville  Huntsville     AL
# 4                    Alabama State University  Montgomery     AL
# ...                                       ...         ...    ...
# 5984          Galen Health Institutes-Houston     Houston     TX
# 5985        Galen Health Institutes-Pikeville   Pikeville     KY
# 5986                   Stellar Career College     Chicago     IL
# 5987  Commonwealth University of Pennsylvania  Bloomsburg     PA
# 5988          Pennsylvania Western University  California     PA
#
#                                           INSTURL  PREDDEG  HIGHDEG  \
# 0                                   www.aamu.edu/        3        4
# ...

# %%
# save combined data to csv file
data.to_csv('data/data_cleaned.csv', index=False)
